# %% [markdown]
# # Convexity of the XOR Problem

# %% [markdown]
# ## Contents
# [XOR Distribution](#XOR-Distribution)<br>
# [Building MLP](#Building-MLP)<br>

# %% [markdown]
# ## Things to do:
# - Think about how to plot out the cost function
# - Change the initializer to random
# - Animate the live graph

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %config InLineBackend.figure_format = 'svg' #magic code that gets svg rendered graphics. makes the plot nicer
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## XOR Distribution
# [Back to Contents](#Contents)

# %%
from data_utils import generate_XOR_distribution
Input,Output = generate_XOR_distribution(1)
plt.scatter(Input[:,0],Input[:,1], s = 50, c = Output, alpha= 0.5)
plt.show()

# %% [markdown]
# ## Building MLP
# [Back to Contents](#Contents)

# %%
# Building mlp
n_input = 2
n_hidden = 10
n_output = 2

X = tf.placeholder(tf.float32, shape = [None,n_input], name = "Input")
W1 = tf.get_variable(name = 'W1', shape=[n_input,n_hidden], 
                     dtype=tf.float32,initializer=tf.contrib.layers.xavier_initializer())
W2 = tf.get_variable(name = 'W2', shape=[n_hidden,n_output], 
                     dtype=tf.float32,initializer=tf.contrib.layers.xavier_initializer())
b1 = tf.Variable(tf.constant(0.0,shape = [n_hidden],name = 'b1'))
b2 = tf.Variable(tf.constant(0.0,shape = [n_output],name = 'b2'))

# %%
# Onehot encoding output
Output = keras.utils.to_categorical(Output,num_classes=2)

# %%
# Operations
h1 = tf.nn.sigmoid(tf.matmul(X,W1) +b1, name = 'h1') 
Y_hat = tf.nn.sigmoid(tf.matmul(h1,W2) +b2, name = 'Y_hat')

# Training
cost = tf.reduce_mean(tf.squared_difference(Y_hat,Output), name = 'cost')
train = tf.train.AdamOptimizer(learning_rate = 10e-3).minimize(cost)
initOP = tf.global_variables_initializer()

# %%
import time
# Session
with tf.Session() as sess:
    tic = time.time()
    sess.run(initOP)
    epoch = 10
    for i in range(epoch):
        error = cost.eval(feed_dict={X:Input})
        sess.run(train,feed_dict={X:Input})
        toc = time.time()
        print("Epoch: {}, Error: {}, Time Taken: {}".format(i, error, toc-tic))
# Out:
# Epoch: 0, Error: 0.2913972735404968, Time Taken: 0.4694845676422119
# Epoch: 1, Error: 0.2877194881439209, Time Taken: 0.4744832515716553
# Epoch: 2, Error: 0.284283310174942, Time Taken: 0.4784860610961914
# Epoch: 3, Error: 0.28104686737060547, Time Taken: 0.4834887981414795
# Epoch: 4, Error: 0.27792060375213623, Time Taken: 0.48799920082092285
# Epoch: 5, Error: 0.27485424280166626, Time Taken: 0.49300312995910645
# Epoch: 6, Error: 0.2718653678894043, Time Taken: 0.49700474739074707
# Epoch: 7, Error: 0.2690012753009796, Time Taken: 0.5015170574188232
# Epoch: 8, Error: 0.266308069229126, Time Taken: 0.5055198669433594
# Epoch: 9, Error: 0.2638171911239624, Time Taken: 0.5105233192443848
